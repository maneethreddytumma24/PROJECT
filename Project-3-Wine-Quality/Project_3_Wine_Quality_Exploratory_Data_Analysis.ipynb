# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b0607571-2755-4566-8b59-6a73c629a4ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0607571-2755-4566-8b59-6a73c629a4ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("winequality-red.csv", sep=";")

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
print("Shape:", df.shape)

print("\nColumns:")
print(df.columns)

print("\nInformation:")
df.info()
# Out:
# Shape: (1599, 12)
#
# Columns:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')
#
# Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
print("Duplicate Rows:", df.duplicated().sum())

df.drop_duplicates(inplace=True)

print("Shape after removing duplicates:", df.shape)
# Out:
# Duplicate Rows: 240
# Shape after removing duplicates: (1359, 12)

# %%
print("Mean")
print(df.mean())

print("\nMedian")
print(df.median())

print("\nMode")
print(df.mode().iloc[0])

print("\nVariance")
print(df.var())

print("\nStandard Deviation")
print(df.std())
# Out:
# Mean
# fixed acidity            8.310596
# volatile acidity         0.529478
# citric acid              0.272333
# residual sugar           2.523400
# chlorides                0.088124
# free sulfur dioxide     15.893304
# total sulfur dioxide    46.825975
# density                  0.996709
# pH                       3.309787
# sulphates                0.658705
# alcohol                 10.432315
# quality                  5.623252
# dtype: float64
#
# Median
# fixed acidity            7.9000
# volatile acidity         0.5200
# citric acid              0.2600
# residual sugar           2.2000
# chlorides                0.0790
# free sulfur dioxide     14.0000
# total sulfur dioxide    38.0000
# density                  0.9967
# pH                       3.3100
# sulphates                0.6200
# alcohol                 10.2000
# quality                  6.0000
# dtype: float64
#
# Mode
# fixed acidity            7.2000
# volatile acidity         0.5000
# ...

# %%
Q1 = df["alcohol"].quantile(0.25)
Q3 = df["alcohol"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df["alcohol"] < lower) | (df["alcohol"] > upper)]

print("Number of Outliers:", len(outliers))

outliers.head()
# Out:
# Number of Outliers: 12
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 142            5.2              0.34         0.00             1.8      0.050
# 467            8.8              0.46         0.45             2.6      0.065
# 588            5.0              0.42         0.24             2.0      0.060
# 652           15.9              0.36         0.65             7.5      0.096
# 821            4.9              0.42         0.00             2.1      0.048
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 142                 27.0                  63.0  0.99160  3.68       0.79
# 467                  7.0                  18.0  0.99470  3.32       0.79
# 588                 19.0                  50.0  0.99170  3.72       0.74
# 652                 22.0                  71.0  0.99760  2.98       0.84
# 821                 16.0                  42.0  0.99154  3.71       0.74
#
#      alcohol  quality
# ...

# %%
df["alcohol"] = np.where(df["alcohol"] > upper, upper, df["alcohol"])
df["alcohol"] = np.where(df["alcohol"] < lower, lower, df["alcohol"])

print("Outliers treated successfully!")
# Out:
# Outliers treated successfully!

# %%
correlation = df.corr(numeric_only=True)

correlation
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.062906         -0.197587     0.106046
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(10,8))

plt.imshow(correlation, cmap="coolwarm", interpolation="nearest")

plt.colorbar()

plt.xticks(range(len(correlation.columns)), correlation.columns, rotation=90)

plt.yticks(range(len(correlation.columns)), correlation.columns)

plt.title("Correlation Heatmap")

plt.show()

# %%
good_wines = df[df["quality"] >= 7]

good_wines.head()

high_alcohol = df[df["alcohol"] > 12]

high_alcohol.head()

df.sort_values(by="quality", ascending=False).head(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1549            7.4              0.36         0.30             1.8      0.074
# 1403            7.2              0.33         0.33             1.7      0.061
# 481             9.4              0.30         0.56             2.8      0.080
# 495            10.7              0.35         0.53             2.6      0.070
# 1120            7.9              0.54         0.34             2.5      0.076
# 588             5.0              0.42         0.24             2.0      0.060
# 1449            7.2              0.38         0.31             2.0      0.056
# 1061            9.1              0.40         0.50             1.8      0.071
# 455            11.3              0.62         0.67             5.2      0.086
# 440            12.6              0.31         0.72             2.2      0.072
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.sort_values(by="quality", ascending=False).head(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1549            7.4              0.36         0.30             1.8      0.074
# 1403            7.2              0.33         0.33             1.7      0.061
# 481             9.4              0.30         0.56             2.8      0.080
# 495            10.7              0.35         0.53             2.6      0.070
# 1120            7.9              0.54         0.34             2.5      0.076
# 588             5.0              0.42         0.24             2.0      0.060
# 1449            7.2              0.38         0.31             2.0      0.056
# 1061            9.1              0.40         0.50             1.8      0.071
# 455            11.3              0.62         0.67             5.2      0.086
# 440            12.6              0.31         0.72             2.2      0.072
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.groupby("quality")["alcohol"].mean()
df.groupby("quality")["pH"].mean()
df.groupby("quality")["sulphates"].mean()
# Out:
# quality
# 3    0.570000
# 4    0.596415
# 5    0.623570
# 6    0.674542
# 7    0.742635
# 8    0.774706
# Name: sulphates, dtype: float64

# %%
plt.figure(figsize=(8,5))

df["quality"].value_counts().sort_index().plot(kind="bar")

plt.title("Wine Quality Distribution")

plt.xlabel("Quality")

plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df["alcohol"], bins=20)

plt.title("Alcohol Distribution")

plt.xlabel("Alcohol")

plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(df["alcohol"])

plt.title("Alcohol Content")

plt.xlabel("Wine Sample")

plt.ylabel("Alcohol")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df["alcohol"], df["quality"])

plt.title("Alcohol vs Quality")

plt.xlabel("Alcohol")

plt.ylabel("Quality")

plt.show()

# %%
plt.figure(figsize=(6,5))

plt.boxplot(df["alcohol"])

plt.title("Box Plot of Alcohol")

plt.ylabel("Alcohol")

plt.show()

# %% [markdown]
# # Wine Quality Exploratory Data Analysis
#
# ## Objective
# Analyze the Wine Quality dataset to understand the factors affecting wine quality.
#
# ## Dataset
# - Total Records: 1599 (before removing duplicates)
# - Features: 12
#
# ## Data Cleaning
# - Checked for missing values.
# - Removed duplicate records.
# - Treated alcohol outliers using the IQR method.
#
# ## Statistical Analysis
# - Mean
# - Median
# - Mode
# - Variance
# - Standard Deviation
#
# ## Correlation Analysis
# A correlation matrix was generated to identify relationships among numerical features.
#
# ## Visualizations
# - Bar Chart
# - Histogram
# - Line Graph
# - Scatter Plot
# - Box Plot
# - Correlation Heatmap
#
# ## Key Findings
# - Alcohol content generally increases with wine quality.
# - Some features have positive and negative correlations with quality.
# - Most wines fall within the middle quality range.
#
# ## Conclusion
# The dataset was successfully cleaned and analyzed. Correlation analysis and visualizations helped identify important characteristics associated with wine quality.
