# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Display all columns
pd.set_option("display.max_columns", None)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3c3fce89-0a57-45a4-879e-d394986ab9fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c3fce89-0a57-45a4-879e-d394986ab9fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("student_data.csv")   # Replace with your filename if different

df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         3       yes     no  yes
# 3    home   mother           1          3         0        no    yes  yes
# 4    home   father           1          2         0        no    yes  yes
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# ...

# %%
print("Shape of Dataset:", df.shape)

print("\nColumn Names:")
print(df.columns)

print("\nDataset Information:")
df.info()
# Out:
# Shape of Dataset: (395, 33)
#
# Column Names:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
# ...

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
print("Missing Values in Each Column:")
df.isnull().sum()
# Out:
# Missing Values in Each Column:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
print("========== MEAN ==========")
print(df.mean(numeric_only=True))

print("\n========== MEDIAN ==========")
print(df.median(numeric_only=True))

print("\n========== MODE ==========")
print(df.mode().iloc[0])

print("\n========== VARIANCE ==========")
print(df.var(numeric_only=True))

print("\n========== STANDARD DEVIATION ==========")
print(df.std(numeric_only=True))
# Out:
# ========== MEAN ==========
# age           16.696203
# Medu           2.749367
# Fedu           2.521519
# traveltime     1.448101
# studytime      2.035443
# failures       0.334177
# famrel         3.944304
# freetime       3.235443
# goout          3.108861
# Dalc           1.481013
# Walc           2.291139
# health         3.554430
# absences       5.708861
# G1            10.908861
# G2            10.713924
# G3            10.415190
# dtype: float64
#
# ========== MEDIAN ==========
# age           17.0
# Medu           3.0
# Fedu           2.0
# traveltime     1.0
# studytime      2.0
# failures       0.0
# famrel         4.0
# freetime       3.0
# goout          3.0
# Dalc           1.0
# Walc           2.0
# health         4.0
# absences       4.0
# G1            11.0
# G2            11.0
# G3            11.0
# dtype: float64
#
# ========== MODE ==========
# school            GP
# sex                F
# age               16
# address            U
# famsize          GT3
# ...

# %%
Q1 = df["G3"].quantile(0.25)
Q3 = df["G3"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df["G3"] < lower) | (df["G3"] > upper)]

print("Number of Outliers:", len(outliers))
outliers
# Out:
# Number of Outliers: 0
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3]
# Index: []

# %%
correlation = df.corr(numeric_only=True)

correlation
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %%
plt.figure(figsize=(6,4))

df["sex"].value_counts().plot(kind="bar")

plt.title("Male vs Female Students")
plt.xlabel("Gender")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(df["G3"])

plt.title("Final Grade of Students")
plt.xlabel("Student Index")
plt.ylabel("Final Grade")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df["G3"], bins=10)

plt.title("Distribution of Final Grades")
plt.xlabel("Final Grade")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df["studytime"], df["G3"])

plt.title("Study Time vs Final Grade")
plt.xlabel("Study Time")
plt.ylabel("Final Grade")

plt.show()

# %%
g3_corr = correlation["G3"].sort_values(ascending=False)

print(g3_corr)
# Out:
# G3            1.000000
# G2            0.904868
# G1            0.801468
# Medu          0.217147
# Fedu          0.152457
# studytime     0.097820
# famrel        0.051363
# absences      0.034247
# freetime      0.011307
# Walc         -0.051939
# Dalc         -0.054660
# health       -0.061335
# traveltime   -0.117142
# goout        -0.132791
# age          -0.161579
# failures     -0.360415
# Name: G3, dtype: float64

# %%
print("Correlation of all features with Final Grade (G3):")

g3_corr = correlation["G3"].sort_values(ascending=False)

print(g3_corr)
# Out:
# Correlation of all features with Final Grade (G3):
# G3            1.000000
# G2            0.904868
# G1            0.801468
# Medu          0.217147
# Fedu          0.152457
# studytime     0.097820
# famrel        0.051363
# absences      0.034247
# freetime      0.011307
# Walc         -0.051939
# Dalc         -0.054660
# health       -0.061335
# traveltime   -0.117142
# goout        -0.132791
# age          -0.161579
# failures     -0.360415
# Name: G3, dtype: float64

# %% [markdown]
# # Exploratory Data Analysis (EDA) Summary
#
# ## Dataset Overview
# - Total Records: 395
# - Total Columns: 33
#
# ## Data Cleaning
# - Missing Values: 0
# - Duplicate Records: 0
# - Dataset was already clean and required no preprocessing.
#
# ## Statistical Analysis
# - Average Final Grade (G3): 10.42
# - Average Study Time: 2.04
# - Average Absences: 5.71
#
# ## Correlation Analysis
# - G2 has the strongest positive correlation with G3.
# - G1 also has a strong positive correlation with G3.
# - Failures have a negative impact on final grades.
#
# ## Outlier Analysis
# - Outliers were checked using the IQR method.
#
# ## Visualizations Created
# - Bar Chart
# - Line Chart
# - Histogram
# - Scatter Plot
# - Correlation Heatmap
#
# ## Conclusion
# Students with better first and second period grades generally perform better in the final exam. Higher study time tends to improve performance, while failures negatively affect final grades.
